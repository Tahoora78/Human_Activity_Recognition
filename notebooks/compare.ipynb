# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["CNN", "LSTM", "Stacked_lstm", "depp CNN-LSTM"])
ypoints = np.array([0.926885, 0.939258, 0.944203, 0.931106])
plt.ylabel("Accuracy")

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["CNN", "LSTM", "Stacked_lstm", "depp CNN-LSTM"])
ypoints = np.array([0.928336, 0.940232, 0.94567, 0.931802])
plt.ylabel("Precision")

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["CNN", "LSTM", "Stacked_lstm", "depp CNN-LSTM"])
ypoints = np.array([0.928336, 0.940972, 0.946028, 0.933166])
plt.ylabel("Recall")

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["CNN", "LSTM", "Stacked_lstm", "depp CNN-LSTM"])
ypoints = np.array([0.926241, 0.939891, 0.944395, 0.931187])
plt.ylabel("f1-score")

plt.plot(xpoints, ypoints)
plt.show()
